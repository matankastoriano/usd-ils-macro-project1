# %%
# !pip install fredapi

# %%
import fredapi as fa
import pandas as pd
from fredapi import Fred

# %%
fred = fa.Fred(api_key="api_key")

# %%
cpi_us = fred.get_series("CPIAUCSL", observation_start="2000-01-01")
cpi_us.tail()
# Out:
# 2026-02-01    327.460
# 2026-03-01    330.293
# 2026-04-01    332.407
# 2026-05-01    333.979
# 2026-06-01    332.568
# dtype: float64

# %%
cpi_core = fred.get_series("CPILFESL", observation_start="2000-01-01")
cpi_core.tail()
# Out:
# 2026-02-01    333.512
# 2026-03-01    334.165
# 2026-04-01    335.423
# 2026-05-01    336.121
# 2026-06-01    336.065
# dtype: float64

# %%
fedfunds = fred.get_series("FEDFUNDS", observation_start="2000-01-01")
fedfunds.tail()
# Out:
# 2026-02-01    3.64
# 2026-03-01    3.64
# 2026-04-01    3.64
# 2026-05-01    3.63
# 2026-06-01    3.63
# dtype: float64

# %%
dgs10 = fred.get_series("DGS10", observation_start="2000-01-01")
dgs10.tail()
# Out:
# 2026-07-17    4.55
# 2026-07-20    4.60
# 2026-07-21    4.63
# 2026-07-22    4.67
# 2026-07-23    4.71
# dtype: float64

# %%
cpi_il = fred.get_series("ISRCPIALLMINMEI", observation_start="2000-01-01")
cpi_il.tail()
# Out:
# 2024-11-01    116.0550
# 2024-12-01    115.7110
# 2025-01-01    116.3991
# 2025-02-01    116.3991
# 2025-03-01    116.9725
# dtype: float64

# %%
# !pip install sqlalchemy psycopg2-binary

# %%
from sqlalchemy import create_engine

# Format: postgresql://USER:PASSWORD@HOST:PORT/DATABASE
engine = create_engine("postgresql://postgres:password@localhost:5432/usd_ils_macro")

# %%
pd.read_sql("SELECT * FROM indicators", engine)
# Out:
#    indicator_id          code                            name  country_id  \
# 0             1      CPIAUCSL    US CPI (all urban consumers)         1.0
# 1             2      CPILFESL  US core CPI (ex food & energy)         1.0
# 2             3      FEDFUNDS    Effective federal funds rate         1.0
# 3             4         DGS10       US 10-year Treasury yield         1.0
# 4             5       ISR_CPI          Israel CPI (all items)         2.0
# 5             6      BOI_RATE      Bank of Israel policy rate         2.0
# 6             7  USDILS_DAILY      USD/ILS spot exchange rate         NaN
#
#   frequency              units    source
# 0   monthly  index 1982-84=100      FRED
# 1   monthly  index 1982-84=100      FRED
# 2   monthly            percent      FRED
# 3     daily            percent      FRED
# 4   monthly              index       CBS
# 5   monthly            percent       BOI
# 6     daily        ILS per USD  yfinance

# %%
df = cpi_us.reset_index()              # turn the Series into a 2-column DataFrame
df.columns = ["obs_date", "value"]     # name them to match our table
df["indicator_id"] = 1                 # CPIAUCSL is indicator_id 1
df = df[["indicator_id", "obs_date", "value"]]
df = df.dropna(subset=["value"]) # order columns to match the table
df.head()
# Out:
#    indicator_id   obs_date  value
# 0             1 2000-01-01  169.3
# 1             1 2000-02-01  170.0
# 2             1 2000-03-01  171.0
# 3             1 2000-04-01  170.9
# 4             1 2000-05-01  171.2

# %%
def load_series(series, indicator_id, engine):
    df = series.reset_index()
    df.columns = ["obs_date", "value"]
    df["indicator_id"] = indicator_id
    df = df[["indicator_id", "obs_date", "value"]]
    df = df.dropna(subset=["value"])
    df.to_sql("observations", engine, if_exists="append", index=False)
    print(f"Loaded {len(df)} rows for indicator_id {indicator_id}")
    return len(df)

# %%
load_series(cpi_us, 1, engine) 
load_series(cpi_core, 2, engine)    # replace cpi_core with your actual variable name
load_series(fedfunds, 3, engine)
load_series(dgs10,    4, engine)
# Out:
# ---------------------------------------------------------------------------
# UniqueViolation                           Traceback (most recent call last)
# File /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages/sqlalchemy/engine/base.py:2127, in Connection._exec_insertmany_context(self, dialect, context)
#    2126     else:
# -> 2127         dialect.do_execute(
#    2128             cursor,
#    2129             sub_stmt,
#    2130             sub_params,
#    2131             context,
#    2132         )
#    2134 except BaseException as e:
#
# File /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages/sqlalchemy/engine/default.py:952, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     951 def do_execute(self, cursor, statement, parameters, context=None):
# --> 952     cursor.execute(statement, parameters)
#
# UniqueViolation: duplicate key value violates unique constraint "observations_pkey"
# ...

# %%
# !pip install yfinance

# %%
import yfinance as yf

fx = yf.download("ILS=X", start="2000-01-01", auto_adjust=True, progress=False)
fx_close = fx["Close"]["ILS=X"]   # pull just the closing price as a Series
fx_close.tail()
# Out:
# Date
# 2026-07-20    3.03685
# 2026-07-21    3.05383
# 2026-07-22    3.04855
# 2026-07-23    3.05792
# 2026-07-24    3.04930
# Name: ILS=X, dtype: float64

# %%
load_series(fx_close, 7, engine)

# %%
pd.read_sql("""
    SELECT i.code, COUNT(*) AS n_obs,
           MIN(o.obs_date) AS first_date,
           MAX(o.obs_date) AS last_date
    FROM observations o
    JOIN indicators i ON o.indicator_id = i.indicator_id
    GROUP BY i.code
    ORDER BY i.code
""", engine)
# Out:
#            code  n_obs  first_date   last_date
# 0      BOI_RATE    318  2000-01-01  2026-06-01
# 1      CPIAUCSL    317  2000-01-01  2026-06-01
# 2      CPILFESL    317  2000-01-01  2026-06-01
# 3         DGS10   6642  2000-01-03  2026-07-23
# 4      FEDFUNDS    318  2000-01-01  2026-06-01
# 5       ISR_CPI    303  2000-01-01  2025-03-01
# 6  USDILS_DAILY   5874  2003-12-01  2026-07-24

# %%
# !pip install sdmx1

# %%
import sdmx

sdmx.add_source({
    "id": "BOI",
    "name": "Bank of Israel",
    "url": "https://edge.boi.gov.il/FusionEdgeServer/sdmx/v2",
})

boi = sdmx.Client("BOI")
flows = boi.dataflow()
print(flows.dataflow)
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[22], line 10
#       6     "url": "https://edge.boi.gov.il/FusionEdgeServer/sdmx/v2",
#       7 })
#       8
#       9 boi = sdmx.Client("BOI")
# ---> 10 flows = boi.dataflow()
#      11 print(flows.dataflow)
#
# File /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages/sdmx/client.py:477, in Client.get(self, resource_type, resource_id, tofile, use_cache, dry_run, **kwargs)
#     474 try:
#     475     # Send the request
#     476     response = self.session.send(req_prepared, **self._send_kwargs)
# --> 477     response.raise_for_status()
#     478 except requests.exceptions.ConnectionError as e:
#     479     raise e from None
#
# File /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages/requests/models.py:1167, in Response.raise_for_status(self)
# ...

# %%
isr_cpi = fred.get_series("ISRCPIALLMINMEI", observation_start="2000-01-01")
print(isr_cpi.index.min().date(), "→", isr_cpi.index.max().date(), f"({len(isr_cpi)} rows)")
isr_cpi.tail()
# Out:
# 2000-01-01 → 2025-03-01 (303 rows)
# 2024-11-01    116.0550
# 2024-12-01    115.7110
# 2025-01-01    116.3991
# 2025-02-01    116.3991
# 2025-03-01    116.9725
# dtype: float64

# %%
boi_rate = fred.get_series("IRSTCI01ILM156N", observation_start="2000-01-01")
print(boi_rate.index.min().date(), "→", boi_rate.index.max().date(), f"({len(boi_rate)} rows)")
boi_rate.tail()
# Out:
# 2000-01-01 → 2026-06-01 (318 rows)
# 2026-02-01    4.000000
# 2026-03-01    4.000000
# 2026-04-01    4.000000
# 2026-05-01    3.967742
# 2026-06-01    3.750000
# dtype: float64

# %%
load_series(isr_cpi,  5, engine)
load_series(boi_rate, 6, engine)
